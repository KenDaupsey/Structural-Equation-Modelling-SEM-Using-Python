# %% [markdown]
# <a href="https://colab.research.google.com/github/KenDaupsey/Structural-Equation-Modelling-SEM-Using-Python/blob/main/Structural_Equation_Modelling_(SEM)_Using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *** Structural Equation Modelling (SEM) Using Python ***

# %%
### Import Necessary Libraries
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
#! pip install semopy

# %%
from semopy import Model, semplot, calc_stats  # Import calc_stats

# %%
### Load dataset
import pandas as pd
url= ("https://raw.githubusercontent.com/KenDaupsey/Structural-Equation-Modelling-SEM-Using-Python/main/StructuralEquationData.csv")
df= pd.read_csv(url)
df.head()
# Out:
#    Academic_Ability  Motivation  Test_Scores  Homework_Completion  \
# 0         -0.752759    0.009098    88.971150            29.314773
# 1          2.704286    1.789771    98.483062            89.633582
# 2          1.391964    0.899784   100.000000             1.300192
# 3          0.591951    1.211801   100.000000             8.550853
# 4         -2.063888    1.774756    69.819877            20.788626
#
#    Disciplinary_Incidents
# 0                       3
# 1                       2
# 2                       4
# 3                       1
# 4                       2

# %%
### Column Names
df.columns
# Out:
# Index(['Academic_Ability', 'Motivation', 'Test_Scores', 'Homework_Completion',
#        'Disciplinary_Incidents'],
#       dtype='object')

# %%
### Data Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Academic_Ability        275 non-null    float64
#  1   Motivation              275 non-null    float64
#  2   Test_Scores             275 non-null    float64
#  3   Homework_Completion     275 non-null    float64
#  4   Disciplinary_Incidents  275 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 10.9 KB

# %%
### Summary Statistics
df.describe().T
# Out:
#                         count       mean        std        min        25%  \
# Academic_Ability        275.0  -0.003874   1.775599  -2.969630  -1.555757
# Motivation              275.0   0.093212   1.820173  -2.934974  -1.347635
# Test_Scores             275.0  73.662410  18.966704  25.098072  59.422774
# Homework_Completion     275.0  51.226048  29.641579   0.638587  24.803502
# Disciplinary_Incidents  275.0   1.985455   1.380180   0.000000   1.000000
#
#                               50%        75%         max
# Academic_Ability         0.072558   1.567214    2.940323
# Motivation               0.243811   1.660680    2.998306
# Test_Scores             74.450530  89.017420  100.000000
# Homework_Completion     53.697442  78.853409   99.793411
# Disciplinary_Incidents   2.000000   3.000000    6.000000

# %%
# Define the SEM model
model_desc = '''
# Measurement model
Academic_Ability =~ Test_Scores + Homework_Completion
Motivation =~ Disciplinary_Incidents

# Structural model
Test_Scores ~ Academic_Ability + Motivation
Homework_Completion ~ Academic_Ability + Motivation
Disciplinary_Incidents ~ Academic_Ability + Motivation
'''

# %%
# Fit the SEM model
model = Model(model_desc)
sem_results = model.fit(df)  # Replace df with your actual DataFrame

# Print the summary of the SEM model
print(sem_results)
# Out:
# Name of objective: MLW
# Optimization method: SLSQP
# Optimization successful.
# Optimization terminated successfully
# Objective value: 0.003
# Number of iterations: 55
# Params: 10.976 -6.154 -24.630 10.976 48.349 -5.735 -22.032 159.510 -41.413 0.774 504.893 10.754 350.169

# %%
# Analyze parameter estimates
ins = model.inspect()
print(ins)
# Out:
# WARNING:root:Fisher Information Matrix is not PD.Moore-Penrose inverse will be used instead of Cholesky decomposition. See 10.1109/TSP.2012.2208105.
#                       lval  op                    rval    Estimate   Std. Err  \
# 0              Test_Scores   ~        Academic_Ability    1.000000          -
# 1      Homework_Completion   ~        Academic_Ability   10.975796   0.076021
# 2   Disciplinary_Incidents   ~              Motivation    1.000000          -
# 3              Test_Scores   ~        Academic_Ability   -6.153659   0.311835
# 4              Test_Scores   ~              Motivation  -24.630144   1.015636
# 5      Homework_Completion   ~        Academic_Ability   10.975796   0.076021
# 6      Homework_Completion   ~              Motivation   48.348627   0.169326
# 7   Disciplinary_Incidents   ~        Academic_Ability   -5.734589   0.204327
# 8   Disciplinary_Incidents   ~              Motivation  -22.032190   0.783069
# 9         Academic_Ability  ~~        Academic_Ability  159.510272   0.006508
# 10        Academic_Ability  ~~              Motivation  -41.412774   0.023339
# 11              Motivation  ~~              Motivation   10.753824   0.012267
# 12  Disciplinary_Incidents  ~~  Disciplinary_Incidents    0.773633   2.037612
# 13     Homework_Completion  ~~     Homework_Completion  504.892677   0.754333
# 14             Test_Scores  ~~             Test_Scores  350.168782  30.861323
#
#          z-value   p-value
# 0              -         -
# 1     144.377996       0.0
# 2              -         -
# 3     -19.733674       0.0
# 4     -24.250961       0.0
# 5     144.378028       0.0
# 6     285.535159       0.0
# 7     -28.065735       0.0
# 8      -28.13569       0.0
# 9   24510.647226       0.0
# 10  -1774.381457       0.0
# 11    876.657156       0.0
# 12      0.379676  0.704186
# 13    669.323663       0.0
# 14     11.346525       0.0

# %%
# Calculate additional SEM statistics
stats = calc_stats(model)  # Use calc_stats directly
print(stats)
# Out:
#        DoF  DoF Baseline      chi2  chi2 p-value  chi2 Baseline       CFI  \
# Value   -7             3  0.862796           NaN       3.955076 -7.232641
#
#             GFI      AGFI       NFI       TLI  RMSEA        AIC        BIC  \
# Value  0.781851  1.093492  0.781851  4.528275    NaN  25.993725  73.011749
#
#          LogLik
# Value  0.003137
# /usr/local/lib/python3.10/dist-packages/semopy/stats.py:383: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt((chi2 / dof - 1) / (model.n_samples - 1))

# %%
### Visualize Structural Equation Model
# Plot the SEM model with different colors
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot with different colors for different attributes
scatter = ax.scatter(
    df['Academic_Ability'],
    df['Motivation'],
    df['Test_Scores'],
    c=df['Test_Scores'],  # Use Test_Scores as a color indicator
    cmap='viridis',  # Choose a color map
    label='Test Scores'
)

ax.set_xlabel('Academic Ability')
ax.set_ylabel('Motivation')
ax.set_zlabel('Test Scores')

# Add colorbar
cbar = plt.colorbar(scatter, ax=ax, label='Test Scores')
cbar.set_label('Test Scores')

plt.show()

# %%
### Visualize Structural Equation Relationship Plot
# Generate SEM plot and save it to a file
semplot(model, "model.png")
# Out:
# WARNING:root:Fisher Information Matrix is not PD.Moore-Penrose inverse will be used instead of Cholesky decomposition. See 10.1109/TSP.2012.2208105.

# %% [markdown]
# *** Structural Equation Modelling (SEM) Using Python ~ Entire Code ***

# %%
### Import Necessary Libraries
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

## ! pip install semopy ### Switch on to install this

from semopy import Model, semplot, calc_stats  # Import calc_stats

### Load dataset
import pandas as pd
url= ("https://raw.githubusercontent.com/KenDaupsey/Structural-Equation-Modelling-SEM-Using-Python/main/StructuralEquationData.csv")
df= pd.read_csv(url)
df.head()

df.columns

df.info()

df.describe().T

# Define the SEM model
model_desc = '''
# Measurement model
Academic_Ability =~ Test_Scores + Homework_Completion
Motivation =~ Disciplinary_Incidents

# Structural model
Test_Scores ~ Academic_Ability + Motivation
Homework_Completion ~ Academic_Ability + Motivation
Disciplinary_Incidents ~ Academic_Ability + Motivation
'''

# Fit the SEM model
model = Model(model_desc)
sem_results = model.fit(df)  # Replace df with your actual DataFrame

# Print the summary of the SEM model
print(sem_results)

# Analyze parameter estimates
ins = model.inspect()
print(ins)

# Calculate additional SEM statistics
stats = calc_stats(model)  # Use calc_stats directly
print(stats)

### Visualize Structural Equation Model
# Plot the SEM model with different colors
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot with different colors for different attributes
scatter = ax.scatter(
    df['Academic_Ability'],
    df['Motivation'],
    df['Test_Scores'],
    c=df['Test_Scores'],  # Use Test_Scores as a color indicator
    cmap='viridis',  # Choose a color map
    label='Test Scores'
)

ax.set_xlabel('Academic Ability')
ax.set_ylabel('Motivation')
ax.set_zlabel('Test Scores')

# Add colorbar
cbar = plt.colorbar(scatter, ax=ax, label='Test Scores')
cbar.set_label('Test Scores')

plt.show()

### Visualize Structural Equation Relationship Plot
# Generate SEM plot and save it to a file
semplot(model, "model.png")
# Out:
# WARNING:root:Fisher Information Matrix is not PD.Moore-Penrose inverse will be used instead of Cholesky decomposition. See 10.1109/TSP.2012.2208105.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Academic_Ability        275 non-null    float64
#  1   Motivation              275 non-null    float64
#  2   Test_Scores             275 non-null    float64
#  3   Homework_Completion     275 non-null    float64
#  4   Disciplinary_Incidents  275 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 10.9 KB
# Name of objective: MLW
# Optimization method: SLSQP
# Optimization successful.
# Optimization terminated successfully
# Objective value: 0.003
# Number of iterations: 55
# Params: 10.976 -6.154 -24.630 10.976 48.349 -5.735 -22.032 159.510 -41.413 0.774 504.893 10.754 350.169
#                       lval  op                    rval    Estimate   Std. Err  \
# 0              Test_Scores   ~        Academic_Ability    1.000000          -
# 1      Homework_Completion   ~        Academic_Ability   10.975796   0.076021
# 2   Disciplinary_Incidents   ~              Motivation    1.000000          -
# 3              Test_Scores   ~        Academic_Ability   -6.153659   0.311835
# 4              Test_Scores   ~              Motivation  -24.630144   1.015636
# 5      Homework_Completion   ~        Academic_Ability   10.975796   0.076021
# 6      Homework_Completion   ~              Motivation   48.348627   0.169326
# 7   Disciplinary_Incidents   ~        Academic_Ability   -5.734589   0.204327
# 8   Disciplinary_Incidents   ~              Motivation  -22.032190   0.783069
# 9         Academic_Ability  ~~        Academic_Ability  159.510272   0.006508
# 10        Academic_Ability  ~~              Motivation  -41.412774   0.023339
# 11              Motivation  ~~              Motivation   10.753824   0.012267
# 12  Disciplinary_Incidents  ~~  Disciplinary_Incidents    0.773633   2.037612
# 13     Homework_Completion  ~~     Homework_Completion  504.892677   0.754333
# 14             Test_Scores  ~~             Test_Scores  350.168782  30.861323
#
#          z-value   p-value
# 0              -         -
# 1     144.377996       0.0
# 2              -         -
# 3     -19.733674       0.0
# 4     -24.250961       0.0
# 5     144.378028       0.0
# 6     285.535159       0.0
# 7     -28.065735       0.0
# 8      -28.13569       0.0
# 9   24510.647226       0.0
# 10  -1774.381457       0.0
# 11    876.657156       0.0
# 12      0.379676  0.704186
# 13    669.323663       0.0
# 14     11.346525       0.0
#        DoF  DoF Baseline      chi2  chi2 p-value  chi2 Baseline       CFI  \
# Value   -7             3  0.862796           NaN       3.955076 -7.232641
#
#             GFI      AGFI       NFI       TLI  RMSEA        AIC        BIC  \
# Value  0.781851  1.093492  0.781851  4.528275    NaN  25.993725  73.011749
#
#          LogLik
# Value  0.003137
# /usr/local/lib/python3.10/dist-packages/semopy/stats.py:383: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt((chi2 / dof - 1) / (model.n_samples - 1))
# WARNING:root:Fisher Information Matrix is not PD.Moore-Penrose inverse will be used instead of Cholesky decomposition. See 10.1109/TSP.2012.2208105.
